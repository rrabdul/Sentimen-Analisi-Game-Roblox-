# %% [markdown]
# 1. library  installation

# %%
# !pip install google-play-scraper

# %% [markdown]
# 2. Importing Library

# %%
from google_play_scraper import Sort, reviews_all
import csv
import pandas as pd

# %% [markdown]
# 3. Scrapping Details

# %%
# Mengambil semua ulasan dari aplikasi Roblox
scrapreview = reviews_all(
    'com.roblox.client',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=150000
)
scrapreview_limited = scrapreview[:150000]

# %% [markdown]
# 4. Output Details

# %%
dataView = pd.DataFrame(scrapreview_limited)
dataView.head()
# Out:
#                                reviewId         userName  \
# 0  8f7dfdc5-dcbf-4c7b-b8dd-e8f03938ac31  Pengguna Google
# 1  58d87da4-bb0e-4e61-b793-478abb81c19a  Pengguna Google
# 2  cef65af2-97db-4862-8160-6a5fbac90314  Pengguna Google
# 3  a5971649-8d64-40d2-82fe-3cca6d84d885  Pengguna Google
# 4  71a92eb3-79da-4883-8916-a3de2ce30f84  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  game nya seru sekali, Bisa Mabar sama temen, i...      5            946
# 1  game nya seru bangeett! 🤩🤩🤩 aku udah main dari...      5          15124
# ...

# %%
with open('hasil_scraping_Roblox.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    writer.writerow(['content', 'score'])

    for review in scrapreview_limited:
        content = review.get('content')
        if content and 'roblox' in content.lower():  # Cek jika konten tidak None dan mengandung 'roblox'
            writer.writerow([
                content,
                review.get('score', '')
            ])

print("Data yang mengandung 'Roblox' telah disimpan ke hasil_scraping_Roblox.csv")
# Out:
# Data yang mengandung 'Roblox' telah disimpan ke hasil_scraping_Roblox.csv
